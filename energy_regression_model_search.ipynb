# %% [markdown]
# ## Part 1

# %%
import numpy as np
import pandas as pd
import optuna
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn

from sklearn.model_selection import KFold, ShuffleSplit, cross_val_score

from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import ElasticNet

from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from scipy.stats.mstats import winsorize

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data/cosmote.csv', parse_dates=True)

# %%
df = df.fillna(method='ffill')
df['energy_mean_base'] = df['energy_mean'].copy()
df['energy_mean'] = winsorize(df['energy_mean'], limits=[0.05, 0.05])

# %%
df = df.drop(columns=['TCH_CONGESTION', 'TCH_BLOCKING', 'AVG_UL_MAC_UE_TPUT'])  # ? -> df.corr().energy_mean.sort_values(ascending=False)

# %%
random_split = list(ShuffleSplit(n_splits=1, test_size=0.1, random_state=1).split(df))[0]
train_index = random_split[0]
test_index = random_split[1]

# %%
trainDf = df.loc[train_index, ~df.columns.isin(['ID', 'PERIOD_START_TIME', 'energy_mean', 'energy_mean_base'])]

random_split = list(ShuffleSplit(n_splits=1, test_size=0.2, random_state=1).split(trainDf))[0]
train_index = random_split[0]
val_index = random_split[1]

trainDf = df.loc[train_index, ~df.columns.isin(['ID', 'PERIOD_START_TIME', 'energy_mean', 'energy_mean_base'])]
y_train = df.loc[train_index, 'energy_mean']
train_ndarray = np.array(trainDf)
y_train_ndarray = np.array(y_train)

valDf = df.loc[val_index, ~df.columns.isin(['ID', 'PERIOD_START_TIME', 'energy_mean', 'energy_mean_base'])]
y_val = df.loc[val_index, 'energy_mean']
val_ndarray = np.array(valDf)
y_val_ndarray = np.array(y_val)

testDf = df.loc[test_index, ~df.columns.isin(['ID', 'PERIOD_START_TIME', 'energy_mean', 'energy_mean_base'])]
y_test = df.loc[test_index, 'energy_mean']
test_ndarray = np.array(testDf)
y_test_ndarray = np.array(y_test)

# %%
def objective(trial):
    global train_ndarray
    global y_train_ndarray
    global y_val_ndarray

    classifier_name = trial.suggest_categorical("classifier", ["SVR", "RandomForest", "ElasticNet", "KNeighbors"])
    if classifier_name == "SVR":
        kernel = trial.suggest_categorical('kernel', ["rbf"])
        tol_svr = trial.suggest_float('tol_svr', 1e-3, 10, log=True)
        c = trial.suggest_float("c", 1e-1, 1e4, log=True)
        classifier_obj = sklearn.svm.SVR(C=c, kernel=kernel, tol=tol_svr)
    elif classifier_name == "RandomForest":
        max_depth = trial.suggest_int("max_depth", 2, 32, log=True)
        criterion = trial.suggest_categorical("criterion", ['squared_error', 'friedman_mse'])
        max_features = trial.suggest_categorical("max_features", ['sqrt', 'log2', None])
        bootstrap = trial.suggest_categorical("bootstrap", [True, False])
        n_estimators = trial.suggest_int("n_estimators", 10, 960, 50)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 32, log=True)
        min_samples_split = trial.suggest_int("min_samples_split", 5, 50, 5)
        
        classifier_obj = RandomForestRegressor(max_depth=max_depth, n_estimators=n_estimators, criterion=criterion, max_features=max_features, bootstrap=bootstrap, min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split)
    elif classifier_name == "KNeighbors":
        n_neighbors = trial.suggest_int("n_neighbors", 3, 19, 2)
        weights = trial.suggest_categorical("weights", ['uniform', 'distance'])
        
        classifier_obj = KNeighborsRegressor(n_neighbors=n_neighbors, weights=weights)
    elif classifier_name == "ElasticNet":
        alpha = trial.suggest_float("alpha", 0.1, 1)
        l1_ratio = trial.suggest_float("l1_ratio", 0, 1)
        tol_en = trial.suggest_float("tol_en", 1e-10, 1)
        selection = trial.suggest_categorical("selection", ['cyclic', 'random'])
        
        classifier_obj = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, tol=tol_en, selection=selection, precompute=True)
    
    model = classifier_obj.fit(train_ndarray, y_train_ndarray)
    preds = model.predict(val_ndarray)
    train_preds = model.predict(train_ndarray)
    
    train_preds = model.predict(train_ndarray)
    train_rmse = mean_squared_error(y_train_ndarray, train_preds, squared=False)
    train_mape = mean_absolute_percentage_error(y_train_ndarray, train_preds)
    
    val_rmse = mean_squared_error(y_val_ndarray, preds, squared=False)
    val_mape = mean_absolute_percentage_error(y_val_ndarray, preds)
    
    return val_rmse, val_mape, train_rmse, train_mape

# %%
study = optuna.create_study(directions=['minimize', 'minimize', 'minimize', 'minimize'])
study.optimize(objective, n_trials=1000, timeout=3600, n_jobs=-1)
# Out:
# [I 2023-11-05 12:12:07,578] A new study created in memory with name: no-name-d3249c9a-b4a4-4cae-b37a-55f63ac27452
# [I 2023-11-05 12:12:08,190] Trial 1 finished with values: [466.3607091219861, 0.08336629576230259, 416.45159384556194, 0.08118375534870377] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.1649873061530471, 'l1_ratio': 0.7290313349722478, 'tol_en': 0.1674265677380557, 'selection': 'random'}.
# /home/ubuntu/miniconda3/envs/bigoptibase/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 881426148.9778678, tolerance: 715073563.7372984
#   model = cd_fast.enet_coordinate_descent_gram(
# [I 2023-11-05 12:12:08,334] Trial 5 finished with values: [441.0214589529545, 0.08196748879072828, 396.43815414756256, 0.08018800367715655] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.4499687270064092, 'l1_ratio': 0.09301077482008757, 'tol_en': 0.11071462285322087, 'selection': 'random'}.
# [I 2023-11-05 12:12:28,237] Trial 6 finished with values: [395.7981469233278, 0.058516693512927924, 230.64177928335172, 0.03920606451554938] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 3, 'weights': 'uniform'}.
# [I 2023-11-05 12:12:28,247] Trial 10 finished with values: [473.8797577481927, 0.09050185219664196, 430.2360894162274, 0.08949784917066249] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.6172994491208484, 'l1_ratio': 0.8898001438552604, 'tol_en': 0.9092470701756927, 'selection': 'random'}.
# [I 2023-11-05 12:12:28,862] Trial 4 finished with values: [417.7775472644005, 0.058886801183581465, 351.65668378923067, 0.053503989070941] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 15, 'weights': 'uniform'}.
# [I 2023-11-05 12:12:29,047] Trial 0 finished with values: [414.8669128001901, 0.0587422870934196, 342.8695896784879, 0.0526195477374116] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 13, 'weights': 'uniform'}.
# [I 2023-11-05 12:12:29,075] Trial 7 finished with values: [413.1155638967015, 0.058314335793219034, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 19, 'weights': 'distance'}.
# [I 2023-11-05 12:12:29,179] Trial 9 finished with values: [427.6795101838831, 0.05955655998458845, 365.81785616072233, 0.055151439885029026] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 19, 'weights': 'uniform'}.
# [I 2023-11-05 12:12:37,186] Trial 11 finished with values: [423.79080993173164, 0.059127460467643916, 358.8978325079212, 0.054415587270147156] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 17, 'weights': 'uniform'}.
# [I 2023-11-05 12:12:49,409] Trial 8 finished with values: [227.01706347040698, 0.04177953560979421, 164.13885278275623, 0.03278805100187402] and parameters: {'classifier': 'RandomForest', 'max_depth': 23, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 710, 'min_samples_leaf': 4, 'min_samples_split': 35}.
# [I 2023-11-05 12:12:54,510] Trial 2 finished with values: [731.6362369860784, 0.08968261819983796, 679.827806846597, 0.08692682117547543] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'scale', 'tol_svr': 0.0004485899477419193, 'c': 0.2762687568273434}.
# [I 2023-11-05 12:12:55,805] Trial 3 finished with values: [226.57127300133888, 0.043638320637836785, 170.56217788595322, 0.037182962876852334] and parameters: {'classifier': 'RandomForest', 'max_depth': 11, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': False, 'n_estimators': 760, 'min_samples_leaf': 2, 'min_samples_split': 45}.
# [I 2023-11-05 12:12:58,336] Trial 17 finished with values: [335.5484499961303, 0.0635230159588354, 289.17775369710074, 0.06125443418022719] and parameters: {'classifier': 'RandomForest', 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'sqrt', 'bootstrap': False, 'n_estimators': 410, 'min_samples_leaf': 26, 'min_samples_split': 20}.
# [I 2023-11-05 12:13:00,691] Trial 14 finished with values: [824.5885738488978, 0.12422739075928843, 771.2243605910885, 0.11977628528877035] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'auto', 'tol_svr': 0.0028353423727306864, 'c': 2.7104106899006704e-07}.
# [I 2023-11-05 12:13:01,313] Trial 13 finished with values: [824.588573848729, 0.12422739075892456, 771.2243564039885, 0.11977628301148374] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'auto', 'tol_svr': 1.5760384883317395e-06, 'c': 7.5596104916248796e-06}.
# [I 2023-11-05 12:13:04,276] Trial 19 finished with values: [395.7981469233278, 0.058516693512927924, 230.64177928335172, 0.03920606451554938] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 3, 'weights': 'uniform'}.
# [I 2023-11-05 12:13:05,449] Trial 12 finished with values: [263.5142737233736, 0.042896782013000755, 218.05512801032594, 0.03696607589810414] and parameters: {'classifier': 'RandomForest', 'max_depth': 26, 'criterion': 'friedman_mse', 'max_features': None, 'bootstrap': True, 'n_estimators': 260, 'min_samples_leaf': 28, 'min_samples_split': 35}.
# [I 2023-11-05 12:13:06,037] Trial 20 finished with values: [385.52559625299494, 0.05777857999776565, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 3, 'weights': 'distance'}.
# [I 2023-11-05 12:13:06,209] Trial 22 finished with values: [323.3382451572915, 0.06268531622717369, 281.5006530117892, 0.060581669224268754] and parameters: {'classifier': 'RandomForest', 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 310, 'min_samples_leaf': 6, 'min_samples_split': 25}.
# [I 2023-11-05 12:13:06,255] Trial 18 finished with values: [294.73082869317903, 0.05320126557065823, 248.32306484436944, 0.050117794023007194] and parameters: {'classifier': 'RandomForest', 'max_depth': 7, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 460, 'min_samples_leaf': 27, 'min_samples_split': 5}.
# [I 2023-11-05 12:13:06,348] Trial 27 finished with values: [450.4962301685359, 0.08571676429688312, 407.6011339343555, 0.08366397315446646] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.7124443138404213, 'l1_ratio': 0.4644473958395573, 'tol_en': 0.8608723432199745, 'selection': 'cyclic'}.
# [I 2023-11-05 12:13:12,714] Trial 21 finished with values: [269.2294465597449, 0.04697632933917002, 225.04294003700596, 0.04324892435207679] and parameters: {'classifier': 'RandomForest', 'max_depth': 8, 'criterion': 'friedman_mse', 'max_features': None, 'bootstrap': True, 'n_estimators': 110, 'min_samples_leaf': 20, 'min_samples_split': 45}.
# [I 2023-11-05 12:13:12,790] Trial 29 finished with values: [450.54984261395566, 0.08576309672507007, 407.6892857468353, 0.08370801084549433] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.8228272646599971, 'l1_ratio': 0.46133337850877665, 'tol_en': 0.8446359939753109, 'selection': 'cyclic'}.
# [I 2023-11-05 12:13:15,869] Trial 25 finished with values: [287.6059391228008, 0.05294034276456063, 242.23568014861038, 0.04979599440507713] and parameters: {'classifier': 'RandomForest', 'max_depth': 7, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 410, 'min_samples_leaf': 22, 'min_samples_split': 50}.
# [I 2023-11-05 12:13:16,101] Trial 31 finished with values: [321.78227264307964, 0.055562282229648666, 273.4333142725627, 0.052573114127309986] and parameters: {'classifier': 'RandomForest', 'max_depth': 7, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 10, 'min_samples_leaf': 30, 'min_samples_split': 15}.
# [I 2023-11-05 12:13:27,296] Trial 28 finished with values: [481.3944825089298, 0.07969108724737993, 432.1217417037538, 0.07759766679338621] and parameters: {'classifier': 'SVR', 'kernel': 'poly', 'gamma': 'scale', 'tol_svr': 2.8939535675064932e-05, 'c': 89.52453226304242}.
# [I 2023-11-05 12:13:35,904] Trial 23 finished with values: [443.40703878573765, 0.05883398249860308, 401.49225602492817, 0.057438400479865724] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'scale', 'tol_svr': 2.142043702640573e-08, 'c': 1107.5559574830042}.
# [I 2023-11-05 12:13:36,831] Trial 33 finished with values: [386.123554514296, 0.056449965833336196, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 9, 'weights': 'distance'}.
# [I 2023-11-05 12:13:36,941] Trial 35 finished with values: [476.9261507046427, 0.08941687065654616, 433.25941060946093, 0.08823500451586697] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.6498198523757769, 'l1_ratio': 0.909355889885442, 'tol_en': 0.35907489782548097, 'selection': 'random'}.
# [I 2023-11-05 12:13:36,983] Trial 36 finished with values: [450.4744678231441, 0.08569511649650327, 407.5610916553022, 0.08364299025982562] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.41643873586225977, 'l1_ratio': 0.13313288803611334, 'tol_en': 0.6787119833808419, 'selection': 'cyclic'}.
# [I 2023-11-05 12:13:37,278] Trial 24 finished with values: [824.5885723684535, 0.12422738756948347, 771.1876571307632, 0.11975632416980579] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'auto', 'tol_svr': 6.63094837917517e-05, 'c': 0.06389382261297565}.
# [I 2023-11-05 12:13:44,993] Trial 34 finished with values: [386.123554514296, 0.056449965833336196, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 9, 'weights': 'distance'}.
# [I 2023-11-05 12:13:45,599] Trial 37 finished with values: [404.296452482205, 0.057833558505281366, 331.5426408233526, 0.0513481091446922] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 11, 'weights': 'uniform'}.
# [I 2023-11-05 12:13:58,309] Trial 15 finished with values: [251.67414737379445, 0.04322876209740866, 184.10752836076688, 0.03310450506554736] and parameters: {'classifier': 'RandomForest', 'max_depth': 15, 'criterion': 'squared_error', 'max_features': None, 'bootstrap': False, 'n_estimators': 360, 'min_samples_leaf': 12, 'min_samples_split': 45}.
# /home/ubuntu/miniconda3/envs/bigoptibase/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 809628869.305984, tolerance: 688821961.3973514
#   model = cd_fast.enet_coordinate_descent_gram(
# [I 2023-11-05 12:13:58,319] Trial 41 finished with values: [441.29719573843346, 0.0821336413347635, 396.9610357383679, 0.08034962909032856] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.8956839313642758, 'l1_ratio': 0.2485322299631142, 'tol_en': 0.10665009523011926, 'selection': 'cyclic'}.
# [I 2023-11-05 12:14:03,335] Trial 26 finished with values: [812.372020377132, 0.1329470762885043, 11.972846284516093, 5.7172549625242285e-05] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'auto', 'tol_svr': 0.1173161375425032, 'c': 110040.48316486902}.
# [I 2023-11-05 12:14:04,203] Trial 39 finished with values: [824.5428182498356, 0.12422387879635266, 771.179327982164, 0.11977288261013667] and parameters: {'classifier': 'SVR', 'kernel': 'poly', 'gamma': 'scale', 'tol_svr': 9.796118205802185e-10, 'c': 4.523944057339762e-07}.
# [I 2023-11-05 12:14:07,419] Trial 42 finished with values: [385.9499894418734, 0.057682392107546734, 275.92101435606224, 0.04507071757882545] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 5, 'weights': 'uniform'}.
# [I 2023-11-05 12:14:10,440] Trial 38 finished with values: [824.7296932944339, 0.12419563371216494, 766.9297662702094, 0.11733898665612899] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'auto', 'tol_svr': 1.834731293626516e-06, 'c': 7.757943363440041}.
# [I 2023-11-05 12:14:12,445] Trial 43 finished with values: [384.84205300740746, 0.07053359198848208, 334.74065027126994, 0.06829805279871702] and parameters: {'classifier': 'RandomForest', 'max_depth': 3, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 760, 'min_samples_leaf': 7, 'min_samples_split': 45}.
# [I 2023-11-05 12:14:12,511] Trial 47 finished with values: [449.63921486094546, 0.0852277158547219, 406.60117005514087, 0.08319205174502999] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.5892448890060623, 'l1_ratio': 0.8758652621703115, 'tol_en': 0.5734869082861179, 'selection': 'cyclic'}.
# [I 2023-11-05 12:14:18,686] Trial 40 finished with values: [720.3880765389571, 0.08604827246924271, 669.3021770547116, 0.08365694155037874] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'scale', 'tol_svr': 9.69303734261567e-06, 'c': 0.4024632087168692}.
# [I 2023-11-05 12:14:18,711] Trial 49 finished with values: [454.6049857372536, 0.08539717819799006, 408.599804073776, 0.08318671091819815] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.8862079582634962, 'l1_ratio': 0.7578421483734624, 'tol_en': 0.8467740291818545, 'selection': 'random'}.
# [I 2023-11-05 12:14:22,175] Trial 46 finished with values: [213.77110669064297, 0.03975354808636903, 129.8269520461825, 0.02540595994861304] and parameters: {'classifier': 'RandomForest', 'max_depth': 27, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 260, 'min_samples_leaf': 2, 'min_samples_split': 15}.
# [I 2023-11-05 12:14:30,064] Trial 45 finished with values: [246.55175951643537, 0.043482901064968514, 184.02512350272812, 0.035127875473407406] and parameters: {'classifier': 'RandomForest', 'max_depth': 28, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': False, 'n_estimators': 410, 'min_samples_leaf': 23, 'min_samples_split': 5}.
# [I 2023-11-05 12:14:37,668] Trial 52 finished with values: [468.347583531552, 0.08334780972710615, 410.327924458909, 0.08012516309945344] and parameters: {'classifier': 'RandomForest', 'max_depth': 2, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 910, 'min_samples_leaf': 2, 'min_samples_split': 5}.
# [I 2023-11-05 12:14:38,633] Trial 32 finished with values: [812.372020699867, 0.13294707378511542, 11.972505826186044, 5.711672661372391e-05] and parameters: {'classifier': 'SVR', 'kernel': 'rbf', 'gamma': 'auto', 'tol_svr': 0.00021757299620408472, 'c': 66729728.63281163}.
# [I 2023-11-05 12:14:38,700] Trial 54 finished with values: [449.5252645276092, 0.08518592038375876, 406.49444533015526, 0.08314822240157178] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.824348563893337, 'l1_ratio': 0.9270686204878043, 'tol_en': 0.9898792865633188, 'selection': 'cyclic'}.
# [I 2023-11-05 12:14:41,697] Trial 44 finished with values: [122980.70568131743, 26.12096870816298, 121899.43463988193, 25.8816192363071] and parameters: {'classifier': 'SVR', 'kernel': 'sigmoid', 'gamma': 'scale', 'tol_svr': 1.0298461911400956e-07, 'c': 310.12506257465435}.
# [I 2023-11-05 12:14:43,200] Trial 55 finished with values: [464.42147961945295, 0.08425589092906491, 407.1383551261358, 0.08093489167848039] and parameters: {'classifier': 'RandomForest', 'max_depth': 2, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 510, 'min_samples_leaf': 7, 'min_samples_split': 5}.
# [I 2023-11-05 12:14:47,843] Trial 53 finished with values: [378.1702418475354, 0.0562368133311297, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 7, 'weights': 'distance'}.
# [I 2023-11-05 12:14:47,865] Trial 58 finished with values: [449.3590531009204, 0.08512273346027054, 406.34774213745897, 0.08308144629520316] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.9323942399976921, 'l1_ratio': 0.9520031444579672, 'tol_en': 0.7985176731906312, 'selection': 'cyclic'}.
# [I 2023-11-05 12:14:50,557] Trial 56 finished with values: [395.7981469233278, 0.058516693512927924, 230.64177928335172, 0.03920606451554938] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 3, 'weights': 'uniform'}.
# [I 2023-11-05 12:14:51,349] Trial 50 finished with values: [336.5190462603681, 0.06778410954935549, 299.97458141932464, 0.06649895317003168] and parameters: {'classifier': 'RandomForest', 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': None, 'bootstrap': False, 'n_estimators': 360, 'min_samples_leaf': 3, 'min_samples_split': 40}.
# [I 2023-11-05 12:14:52,551] Trial 57 finished with values: [387.4390251850307, 0.057090127911972106, 301.73525635522196, 0.04809018697991913] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 7, 'weights': 'uniform'}.
# [I 2023-11-05 12:14:55,854] Trial 59 finished with values: [385.52559625299494, 0.05777857999776565, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 3, 'weights': 'distance'}.
# [I 2023-11-05 12:14:59,033] Trial 60 finished with values: [409.21291740255845, 0.057956766537567456, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 17, 'weights': 'distance'}.
# [I 2023-11-05 12:14:59,089] Trial 64 finished with values: [490.2507308023, 0.09096830340146088, 435.58430113981956, 0.0874071792829115] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.1965957098477456, 'l1_ratio': 0.5218232190030138, 'tol_en': 0.5176702879864166, 'selection': 'random'}.
# [I 2023-11-05 12:14:59,910] Trial 51 finished with values: [814.2438858216661, 0.09559356290726916, 763.3219901617992, 0.09334062053896006] and parameters: {'classifier': 'SVR', 'kernel': 'sigmoid', 'gamma': 'scale', 'tol_svr': 0.002093858309040521, 'c': 0.8045788874795538}.
# [I 2023-11-05 12:15:01,530] Trial 62 finished with values: [427.6795101838831, 0.05955655998458845, 365.81785616072233, 0.055151439885029026] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 19, 'weights': 'uniform'}.
# [I 2023-11-05 12:15:04,488] Trial 63 finished with values: [385.9499894418734, 0.057682392107546734, 275.92101435606224, 0.04507071757882545] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 5, 'weights': 'uniform'}.
# [I 2023-11-05 12:15:07,411] Trial 66 finished with values: [376.6740288561023, 0.07078519661186504, 328.39199147132433, 0.0684576486639645] and parameters: {'classifier': 'RandomForest', 'max_depth': 3, 'criterion': 'squared_error', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 560, 'min_samples_leaf': 2, 'min_samples_split': 25}.
# [I 2023-11-05 12:15:10,027] Trial 67 finished with values: [417.7775472644005, 0.058886801183581465, 351.65668378923067, 0.053503989070941] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 15, 'weights': 'uniform'}.
# [I 2023-11-05 12:15:14,048] Trial 65 finished with values: [283.5713818950376, 0.04562596247919072, 214.9476218281661, 0.0358692713129596] and parameters: {'classifier': 'RandomForest', 'max_depth': 18, 'criterion': 'squared_error', 'max_features': None, 'bootstrap': False, 'n_estimators': 60, 'min_samples_leaf': 25, 'min_samples_split': 5}.
# [I 2023-11-05 12:15:18,324] Trial 70 finished with values: [386.123554514296, 0.056449965833336196, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 9, 'weights': 'distance'}.
# [I 2023-11-05 12:15:18,474] Trial 72 finished with values: [447.279465963954, 0.08469643833607067, 404.0664152353307, 0.08294445955702832] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.9567351060598056, 'l1_ratio': 0.19226776051049466, 'tol_en': 0.18587847567812216, 'selection': 'cyclic'}.
# [I 2023-11-05 12:15:20,916] Trial 69 finished with values: [298.0753630003155, 0.05786551267315661, 257.00914929163207, 0.055485672926880614] and parameters: {'classifier': 'RandomForest', 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'sqrt', 'bootstrap': True, 'n_estimators': 710, 'min_samples_leaf': 4, 'min_samples_split': 50}.
# [I 2023-11-05 12:15:20,950] Trial 74 finished with values: [445.4131533357822, 0.08277086938223038, 399.1769645627481, 0.0809698131239997] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.9568972568902031, 'l1_ratio': 0.6593539844958275, 'tol_en': 0.25000639831777505, 'selection': 'random'}.
# [I 2023-11-05 12:15:22,499] Trial 73 finished with values: [250.56427876323414, 0.05059729531652094, 212.60473902736314, 0.04762792329853156] and parameters: {'classifier': 'RandomForest', 'max_depth': 7, 'criterion': 'squared_error', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 160, 'min_samples_leaf': 2, 'min_samples_split': 10}.
# [I 2023-11-05 12:15:24,703] Trial 61 finished with values: [224.23512114835222, 0.04326825650646745, 169.0198169108338, 0.036670037880753154] and parameters: {'classifier': 'RandomForest', 'max_depth': 11, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 860, 'min_samples_leaf': 2, 'min_samples_split': 15}.
# [I 2023-11-05 12:15:24,772] Trial 77 finished with values: [450.370512357259, 0.08561958708839146, 407.42324539201013, 0.0835726253857058] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.9946777664353491, 'l1_ratio': 0.7276763663610146, 'tol_en': 0.3989624031355698, 'selection': 'cyclic'}.
# [I 2023-11-05 12:15:31,634] Trial 76 finished with values: [427.6795101838831, 0.05955655998458845, 365.81785616072233, 0.055151439885029026] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 19, 'weights': 'uniform'}.
# [I 2023-11-05 12:15:33,304] Trial 71 finished with values: [226.30101370681874, 0.04193356628689002, 163.9347698478634, 0.03369740271855755] and parameters: {'classifier': 'RandomForest', 'max_depth': 15, 'criterion': 'squared_error', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 460, 'min_samples_leaf': 2, 'min_samples_split': 35}.
# [I 2023-11-05 12:15:33,408] Trial 78 finished with values: [377.5294473900262, 0.056791121357478554, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 5, 'weights': 'distance'}.
# [I 2023-11-05 12:15:58,513] Trial 81 finished with values: [280.7137301671296, 0.0451586180507924, 213.27691456226674, 0.035606529099355154] and parameters: {'classifier': 'RandomForest', 'max_depth': 17, 'criterion': 'friedman_mse', 'max_features': None, 'bootstrap': False, 'n_estimators': 110, 'min_samples_leaf': 24, 'min_samples_split': 20}.
# [I 2023-11-05 12:15:58,562] Trial 82 finished with values: [450.6657965067491, 0.08586039533940958, 407.8875009295739, 0.0838038077480232] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.8059728984089471, 'l1_ratio': 0.2397934356924275, 'tol_en': 0.5899714000365878, 'selection': 'cyclic'}.
# [I 2023-11-05 12:16:06,321] Trial 80 finished with values: [217.01790006035372, 0.03854561034383992, 155.7409369311073, 0.030206474613915547] and parameters: {'classifier': 'RandomForest', 'max_depth': 17, 'criterion': 'friedman_mse', 'max_features': None, 'bootstrap': True, 'n_estimators': 210, 'min_samples_leaf': 3, 'min_samples_split': 45}.
# [I 2023-11-05 12:16:10,392] Trial 68 finished with values: [235.93716414726518, 0.045033585645039065, 197.74895541905857, 0.04186480941037834] and parameters: {'classifier': 'RandomForest', 'max_depth': 8, 'criterion': 'squared_error', 'max_features': None, 'bootstrap': True, 'n_estimators': 610, 'min_samples_leaf': 3, 'min_samples_split': 40}.
# [I 2023-11-05 12:16:16,575] Trial 84 finished with values: [397.70659066662296, 0.057413903029407735, 318.8665686085475, 0.049861153140734346] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 9, 'weights': 'uniform'}.
# [I 2023-11-05 12:16:20,238] Trial 85 finished with values: [403.77079137739014, 0.05771599922705273, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 15, 'weights': 'distance'}.
# [I 2023-11-05 12:16:28,623] Trial 87 finished with values: [397.70659066662296, 0.057413903029407735, 318.8665686085475, 0.049861153140734346] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 9, 'weights': 'uniform'}.
# [I 2023-11-05 12:16:30,818] Trial 88 finished with values: [470.98797780577473, 0.08448490492755442, 410.1859869604571, 0.08114422733253462] and parameters: {'classifier': 'RandomForest', 'max_depth': 2, 'criterion': 'squared_error', 'max_features': 'log2', 'bootstrap': False, 'n_estimators': 160, 'min_samples_leaf': 2, 'min_samples_split': 15}.
# [I 2023-11-05 12:16:30,905] Trial 89 finished with values: [468.7326999987271, 0.09273442169424846, 428.78797613596964, 0.09091618338544767] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.857449935014715, 'l1_ratio': 0.0959552516332427, 'tol_en': 0.9394015485425892, 'selection': 'random'}.
# [I 2023-11-05 12:16:33,539] Trial 86 finished with values: [201.8679225157079, 0.03768959587601758, 61.21665592182749, 0.00958147475919035] and parameters: {'classifier': 'RandomForest', 'max_depth': 20, 'criterion': 'squared_error', 'max_features': 'log2', 'bootstrap': False, 'n_estimators': 210, 'min_samples_leaf': 2, 'min_samples_split': 5}.
# [I 2023-11-05 12:16:42,514] Trial 91 finished with values: [409.21291740255845, 0.057956766537567456, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 17, 'weights': 'distance'}.
# [I 2023-11-05 12:16:49,346] Trial 92 finished with values: [218.70808204648102, 0.040429561124241405, 144.06064831200538, 0.028272356590082884] and parameters: {'classifier': 'RandomForest', 'max_depth': 30, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 160, 'min_samples_leaf': 3, 'min_samples_split': 20}.
# [I 2023-11-05 12:17:09,216] Trial 90 finished with values: [824.5881407785382, 0.12422723740920505, 771.2239319567989, 0.11977614139729652] and parameters: {'classifier': 'SVR', 'kernel': 'sigmoid', 'gamma': 'scale', 'tol_svr': 0.0010016381784074466, 'c': 1.1085590229744232e-06}.
# [I 2023-11-05 12:17:18,673] Trial 94 finished with values: [409.21291740255845, 0.057956766537567456, 0.0, 0.0] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 17, 'weights': 'distance'}.
# [I 2023-11-05 12:17:18,738] Trial 95 finished with values: [452.52117087375643, 0.08466163060975543, 414.6201937247149, 0.08307403123217803] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.563121042131563, 'l1_ratio': 0.918345945112171, 'tol_en': 0.8662488718399326, 'selection': 'random'}.
# [I 2023-11-05 12:17:26,689] Trial 96 finished with values: [404.296452482205, 0.057833558505281366, 331.5426408233526, 0.0513481091446922] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 11, 'weights': 'uniform'}.
# [I 2023-11-05 12:17:27,734] Trial 97 finished with values: [307.18664220698065, 0.059210794130870936, 262.6309697233441, 0.056643485424030166] and parameters: {'classifier': 'RandomForest', 'max_depth': 5, 'criterion': 'friedman_mse', 'max_features': 'log2', 'bootstrap': True, 'n_estimators': 60, 'min_samples_leaf': 5, 'min_samples_split': 40}.
# [I 2023-11-05 12:17:27,797] Trial 98 finished with values: [450.3731321063715, 0.08561332141214072, 407.4142279466324, 0.08356601281208606] and parameters: {'classifier': 'ElasticNet', 'alpha': 0.3502166097334227, 'l1_ratio': 0.209045651378565, 'tol_en': 0.7984992637995628, 'selection': 'cyclic'}.
# [I 2023-11-05 12:17:33,536] Trial 93 finished with values: [304.6006509041426, 0.06256372981424038, 270.74459869141526, 0.06099725449923365] and parameters: {'classifier': 'RandomForest', 'max_depth': 4, 'criterion': 'friedman_mse', 'max_features': None, 'bootstrap': True, 'n_estimators': 760, 'min_samples_leaf': 7, 'min_samples_split': 30}.
# [I 2023-11-05 12:17:37,182] Trial 99 finished with values: [404.296452482205, 0.057833558505281366, 331.5426408233526, 0.0513481091446922] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 11, 'weights': 'uniform'}.
# [I 2023-11-05 12:17:42,062] Trial 100 finished with values: [397.70659066662296, 0.057413903029407735, 318.8665686085475, 0.049861153140734346] and parameters: {'classifier': 'KNeighbors', 'n_neighbors': 9, 'weights': 'uniform'}.
# [I 2023-11-05 12:18:00,994] Trial 102 finished with values: [550.4154335236708, 0.09366747885922136, 505.01494320738703, 0.09063728804326406] and parameters: {'classifier': 'SVR', 'kernel': 'poly', 'gamma': 'scale', 'tol_svr': 0.00014885671131247897, 'c': 2.9022414236555263}.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/site-packages/optuna/study/_optimize.py:100, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      99 if len(futures) >= n_jobs:
# --> 100     completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#     101     # Raise if exception occurred in executing the completed futures.
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/concurrent/futures/_base.py:307, in wait(fs, timeout, return_when)
#     305     waiter = _create_and_install_waiters(fs, return_when)
# --> 307 waiter.event.wait(timeout)
#     308 for f in fs:
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 study = optuna.create_study(directions=['minimize', 'minimize', 'minimize', 'minimize'])
# ----> 2 study.optimize(objective, timeout=3600, n_jobs=-1)
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/site-packages/optuna/study/study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/site-packages/optuna/study/_optimize.py:85, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      82 time_start = datetime.datetime.now()
#      83 futures: Set[Future] = set()
# ---> 85 with ThreadPoolExecutor(max_workers=n_jobs) as executor:
#      86     for n_submitted_trials in itertools.count():
#      87         if study._stop_flag:
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniconda3/envs/bigoptibase/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
trials = study.trials_dataframe()
trials.to_csv('out/models_energy_regression.csv')

# %% [markdown]
# ## 1.1 Conclusion from results

# %%
df = pd.read_csv('out/models_energy_regression.csv')
df2 = pd.read_csv('out/models_SVR_energy_regression.csv')
df = pd.concat([df, df2])
df = df.drop(columns=['number', 'system_attrs_nsga2:generation', 'state'])
df = df.rename(columns={'values_0':'val_rmse', 'values_1':'val_mape', 'values_2':'train_rmse', 'values_3':'train_mape'})
df = df.sort_values('val_mape', ascending=True).reset_index(drop=True)

# %%
df.loc[df.params_classifier == 'KNeighbors'].head(200)
# Out:
#      Unnamed: 0    val_rmse  val_mape  train_rmse  train_mape  \
# 182          43  378.170242  0.056237         0.0         0.0
# 183          63  378.170242  0.056237         0.0         0.0
# 184         638  378.170242  0.056237         0.0         0.0
# 185         752  378.170242  0.056237         0.0         0.0
# 186         261  378.170242  0.056237         0.0         0.0
# ..          ...         ...       ...         ...         ...
# 399         605  409.212917  0.057957         0.0         0.0
# 400         948  409.212917  0.057957         0.0         0.0
# 401         338  409.212917  0.057957         0.0         0.0
# 402         293  409.212917  0.057957         0.0         0.0
# 404         590  413.115564  0.058314         0.0         0.0
#
#                  datetime_start           datetime_complete  \
# 182  2023-11-05 14:34:30.366030  2023-11-05 14:34:38.635589
# 183  2023-11-05 14:35:13.157599  2023-11-05 14:35:21.910349
# 184  2023-11-05 14:48:25.466424  2023-11-05 14:48:34.588319
# 185  2023-11-05 14:52:10.456256  2023-11-05 14:52:19.740395
# 186  2023-11-05 14:39:28.255883  2023-11-05 14:39:38.052915
# ..                          ...                         ...
# 399  2023-11-05 14:47:21.419452  2023-11-05 14:47:30.068949
# 400  2023-11-05 14:57:17.889357  2023-11-05 14:57:26.841086
# 401  2023-11-05 14:41:04.633870  2023-11-05 14:41:14.243584
# 402  2023-11-05 14:40:09.001691  2023-11-05 14:40:18.172831
# 404  2023-11-05 14:47:05.315336  2023-11-05 14:47:14.833376
#
#                    duration  params_alpha params_bootstrap params_classifier  \
# 182  0 days 00:00:08.269559           NaN              NaN        KNeighbors
# 183  0 days 00:00:08.752750           NaN              NaN        KNeighbors
# 184  0 days 00:00:09.121895           NaN              NaN        KNeighbors
# 185  0 days 00:00:09.284139           NaN              NaN        KNeighbors
# 186  0 days 00:00:09.797032           NaN              NaN        KNeighbors
# ..                      ...           ...              ...               ...
# 399  0 days 00:00:08.649497           NaN              NaN        KNeighbors
# 400  0 days 00:00:08.951729           NaN              NaN        KNeighbors
# 401  0 days 00:00:09.609714           NaN              NaN        KNeighbors
# 402  0 days 00:00:09.171140           NaN              NaN        KNeighbors
# 404  0 days 00:00:09.518040           NaN              NaN        KNeighbors
#
#     params_criterion  params_l1_ratio  params_max_depth params_max_features  \
# 182              NaN              NaN               NaN                 NaN
# 183              NaN              NaN               NaN                 NaN
# 184              NaN              NaN               NaN                 NaN
# 185              NaN              NaN               NaN                 NaN
# 186              NaN              NaN               NaN                 NaN
# ..               ...              ...               ...                 ...
# 399              NaN              NaN               NaN                 NaN
# 400              NaN              NaN               NaN                 NaN
# 401              NaN              NaN               NaN                 NaN
# 402              NaN              NaN               NaN                 NaN
# 404              NaN              NaN               NaN                 NaN
#
#      params_min_samples_leaf  params_min_samples_split  params_n_estimators  \
# 182                      NaN                       NaN                  NaN
# 183                      NaN                       NaN                  NaN
# 184                      NaN                       NaN                  NaN
# 185                      NaN                       NaN                  NaN
# 186                      NaN                       NaN                  NaN
# ..                       ...                       ...                  ...
# 399                      NaN                       NaN                  NaN
# 400                      NaN                       NaN                  NaN
# 401                      NaN                       NaN                  NaN
# 402                      NaN                       NaN                  NaN
# 404                      NaN                       NaN                  NaN
#
#      params_n_neighbors params_selection  params_tol_en params_weights  \
# 182                 7.0              NaN            NaN       distance
# 183                 7.0              NaN            NaN       distance
# 184                 7.0              NaN            NaN       distance
# 185                 7.0              NaN            NaN       distance
# 186                 7.0              NaN            NaN       distance
# ..                  ...              ...            ...            ...
# 399                17.0              NaN            NaN       distance
# 400                17.0              NaN            NaN       distance
# 401                17.0              NaN            NaN       distance
# 402                17.0              NaN            NaN       distance
# 404                19.0              NaN            NaN       distance
#
#      params_c params_kernel  params_tol_svr
# 182       NaN           NaN             NaN
# 183       NaN           NaN             NaN
# 184       NaN           NaN             NaN
# 185       NaN           NaN             NaN
# 186       NaN           NaN             NaN
# ..        ...           ...             ...
# 399       NaN           NaN             NaN
# 400       NaN           NaN             NaN
# 401       NaN           NaN             NaN
# 402       NaN           NaN             NaN
# 404       NaN           NaN             NaN
#
# [200 rows x 25 columns]
